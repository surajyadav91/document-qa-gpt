# %%
import tiktoken
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# Load PDF file
loader = PyPDFLoader("./SpaceX_NASA_CRS-5_PressKit.pdf")
documents = loader.load()

# %%
## try 2000,400 and 4000,800 for chunk_size, chunk_overlap
text_splitter = RecursiveCharacterTextSplitter(chunk_size=2000, chunk_overlap=400)
split = text_splitter.split_documents(documents)

# %%
token_len = len(encoding.encode('this is a test for token length from tiktoken and openai rembmber it depends on the model you use'))
print(token_len)
# Out:
# 23

# %%
encoding = tiktoken.get_encoding("cl100k_base")
encoding = tiktoken.encoding_for_model("gpt-3.5-turbo")

for i in split:
    token_len = len(encoding.encode(i.page_content))
    print(token_len)
# Out:
# 240
# 246
# 422
# 237
# 429
# 339
# 454
# 361
# 435
# 280
# 517
# 332
# 1
# 1
# 364
# 440
# 386
# 352
# 208
# 136
# 403
# 94
# 445
# 103
# 427
# 349
# 433
# 305
# 465
# 167
# 449
# 177
# 315
# 151
# 409
# 182
# 450
# 162
# 251
# 262

# %%
for i in split[0:5]:
    print(i.page_content)
    print("--------------------------------------------------\n\n\n\n\n\n")
# Out:
# 1
#
#
# SpaceX CRS-5 Mission Press Kit
#
#
# CONTENTS
#
# 3 Mission Overview
# 7 Mission Timeline
# 9 Graphics – Rendezvous, Grapple and Berthing, Departure and Re -Entry
# 11 International Space Station Overview
# 14 CASIS Payloads
# 15 Falcon 9 Overview
# 18 Dragon Overview
# 20 SpaceX Facilities
# 22 SpaceX Overview
# 24 SpaceX Leadership
#
#
# SPACEX MEDIA CONTACT
#
# John Taylor
# Director of Communications
# 310-363-6703
# media@spacex.com
#
#
# NASA PUBLIC AFFAIRS  CONTACT S
#
#
#
#
#   Joshua Buck
# Public Affairs Officer
# Human Exploration and Operations
# NASA Headquarters
# 202-358-1100
#
# Stephanie Schierholz
# Public Affairs Officer
# Human Exploration and Operations
# NASA Headquarters
# 202-358-1100  Michael Curie
# News Chief
# Launch Operations
# NASA Kennedy Space Center
# 321-867-2468
#
# George Diller
# Public Affairs Officer
# Launch Operations
# NASA Kennedy Space Center
# 321-867-2468  Dan Huot
# Public Affairs Officer
# International Space Station
# ...

# %%
## store the created chunks in a list
chunks = []
for i in split:
    chunks.append(i.page_content)

# %%
## store this on disk
import pickle
with open('chunks.pkl', 'wb') as f:
    pickle.dump(chunks, f)
